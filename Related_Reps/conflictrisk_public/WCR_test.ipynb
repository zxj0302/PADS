# %%
# %load_ext autoreload
# %autoreload 2
from WCR import WCR
import networkx as nx

# %%
result = WCR(graph_file='../../output/results-theta=0.5/Referendum_/graph.gml').run()
# Out:
# MATLAB engine started
# Set MATLAB to use 1 cores
#
# ----- STARTING MATLAB EXECUTION -----
#
# Running WCROpt with parameters:
#  k=2000, dim=50, min_eig=1e-08, iter=1
# MATLAB Output:
# WCR/ACR optimization started
#
# Calling Mosek 9.1.9: 4189065 variables, 2894 equality constraints
# ------------------------------------------------------------
#
# MOSEK Version 9.1.9 (Build date: 2019-11-21 11:34:40)
# Copyright (c) MOSEK ApS, Denmark. WWW: mosek.com
# Platform: Windows/64-X86
#
# Problem
#   Name                   :
#   Objective sense        : min
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 2894
#   Cones                  : 0
#   Scalar variables       : 0
#   Matrix variables       : 1
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# ...
